# %% [markdown]
# 1-Open the categorical dataframe we created before.
# 2-Plot all the categorical variables with the proper plot. What can you see?
# 3-There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?
# Make any changes you feel are necessary.
# 4-Plot time variable. Can you extract something from it?
# 5-The time variable can be useful. You shoud transform its data into a more useful form. Hint: Day, week, and month as integers might be useful.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
categorical_df = pd.read_csv('categorical_df.csv')

# %%
categorical_df.head()
# Out:
#         state response  coverage education effective_to_date employmentstatus  \
# 0  Washington       No     Basic  Bachelor        2011-02-24         Employed
# 1     Arizona       No  Extended  Bachelor        2011-01-31       Unemployed
# 2      Nevada       No   Premium  Bachelor        2011-02-19         Employed
# 3  California       No     Basic  Bachelor        2011-01-20       Unemployed
# 4  Washington       No     Basic  Bachelor        2011-02-03         Employed
#
#   gender location_code marital_status        policy renew_offer_type  \
# 0      F      Suburban        Married  Corporate L3           Offer1
# 1      F      Suburban         Single   Personal L3           Offer3
# 2      F      Suburban        Married   Personal L3           Offer1
# 3      M      Suburban        Married  Corporate L2           Offer1
# 4      M         Rural         Single   Personal L1           Offer1
#
#   sales_channel  vehicle_class vehicle_size
# 0         Agent   Two-Door Car      Medsize
# 1         Agent  Four-Door Car      Medsize
# 2         Agent   Two-Door Car      Medsize
# 3   Call Center            SUV      Medsize
# 4         Agent  Four-Door Car      Medsize

# %%
for col in categorical_df.columns:
    sns.countplot(x=col, data=categorical_df)
    plt.xticks(rotation=45)
    plt.show()

# %%
categorical_df['effective_to_date'] = pd.to_datetime(categorical_df['effective_to_date'])

# %%
categorical_df['Day'] = categorical_df['effective_to_date'].dt.day
categorical_df['Month'] = categorical_df['effective_to_date'].dt.month
categorical_df['Year'] = categorical_df['effective_to_date'].dt.year

# %%
categorical_df.drop(columns=['effective_to_date'], inplace=True)

# %%
categorical_df
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status        policy renew_offer_type  \
# 0         Suburban        Married  Corporate L3           Offer1
# 1         Suburban         Single   Personal L3           Offer3
# 2         Suburban        Married   Personal L3           Offer1
# 3         Suburban        Married  Corporate L2           Offer1
# 4            Rural         Single   Personal L1           Offer1
# ...            ...            ...           ...              ...
# 9129         Urban        Married   Personal L1           Offer2
# 9130      Suburban       Divorced  Corporate L3           Offer1
# 9131      Suburban         Single  Corporate L2           Offer1
# 9132      Suburban        Married   Personal L2           Offer3
# 9133      Suburban         Single  Corporate L3           Offer4
#
#      sales_channel  vehicle_class vehicle_size  Day  Month  Year
# 0            Agent   Two-Door Car      Medsize   24      2  2011
# 1            Agent  Four-Door Car      Medsize   31      1  2011
# 2            Agent   Two-Door Car      Medsize   19      2  2011
# 3      Call Center            SUV      Medsize   20      1  2011
# 4            Agent  Four-Door Car      Medsize    3      2  2011
# ...            ...            ...          ...  ...    ...   ...
# 9129           Web  Four-Door Car      Medsize   10      2  2011
# 9130        Branch  Four-Door Car      Medsize   12      2  2011
# 9131        Branch  Four-Door Car      Medsize    6      2  2011
# 9132        Branch  Four-Door Car        Large    3      2  2011
# 9133   Call Center   Two-Door Car      Medsize   14      2  2011
#
# [9134 rows x 16 columns]

# %%
categorical_df.to_csv('categorical_df.csv', index=False)
